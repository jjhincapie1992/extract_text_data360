# %%
import json
import time
from requests import get, post

# %%
########### Python Form Recognizer Async Analyze #############

# Endpoint URL
endpoint = r"https://data360frfr.cognitiveservices.azure.com/"
apim_key = "e3cc1479b98b44719a066ddc7b53a5ea"
model_id = "e368d6bb-c240-4d92-9f1f-92b9ec4ef4e2"
post_url = endpoint + "/formrecognizer/v2.0/custom/models/%s/analyze" % model_id
source = r"C:\Users\Juan Jose Hincapie\Desktop\Transelec\Entregable.1\aceite1.pdf"
params = {
    "includeTextDetails": True
}

headers = {
    # Request headers
    'Content-Type': 'application/pdf',
    'Ocp-Apim-Subscription-Key': apim_key,
}
with open(source, "rb") as f:
    data_bytes = f.read()

try:
    resp = post(url = post_url, data = data_bytes, headers = headers, params = params)
    if resp.status_code != 202:
        print("POST analyze failed:\n%s" % json.dumps(resp.json()))
        quit()
    print("POST analyze succeeded:\n%s" % resp.headers)
    get_url = resp.headers["operation-location"]
except Exception as e:
    print("POST analyze failed:\n%s" % str(e))
    quit()
# Out:
# POST analyze succeeded:
# {'Content-Length': '0', 'Operation-Location': 'https://data360frfr.cognitiveservices.azure.com/formrecognizer/v2.0/custom/models/e368d6bb-c240-4d92-9f1f-92b9ec4ef4e2/analyzeresults/f6cd6787-91c7-4925-a760-26c7861dc289', 'x-envoy-upstream-service-time': '205', 'apim-request-id': '5996ff18-4810-40b2-b366-0321df82b5b8', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'x-content-type-options': 'nosniff', 'Date': 'Wed, 16 Sep 2020 19:53:40 GMT'}

# %%
n_tries = 15
n_try = 0
wait_sec = 5
max_wait_sec = 60
while n_try < n_tries:
    try:
        resp = get(url = get_url, headers = {"Ocp-Apim-Subscription-Key": apim_key})
        resp_json = resp.json()
        if resp.status_code != 200:
            print("GET analyze results failed:\n%s" % json.dumps(resp_json))
            quit()
        status = resp_json["status"]
        if status == "succeeded":
            print("Analysis succeeded:\n%s" % json.dumps(resp_json))
            quit()
        if status == "failed":
            print("Analysis failed:\n%s" % json.dumps(resp_json))
            quit()
        # Analysis still running. Wait and retry.
        time.sleep(wait_sec)
        n_try += 1
        wait_sec = min(2*wait_sec, max_wait_sec)     
    except Exception as e:
        n_try += 1
        msg = "GET analyze results failed:\n%s" % str(e)
        print(msg)
        quit()
print("Analyze operation did not complete within the allocated time.") 
    #with open(output_file, 'w') as outfile:
             #   json.dump(resp_json, outfile, indent=2, sort_keys=True)
            #    pass
# Out:
# GET analyze results failed:
# {"error": {"code": "429", "message": "Requests to the Custom Form - Get Analyze Form Result Operation under Form Recognizer API (v2.0) have exceeded rate limit of your current FormRecognizer F0 pricing tier. Please retry after 5 seconds. To increase your rate limit switch to a paid tier."}}
# GET analyze results failed:
# 'status'
# GET analyze results failed:
# {"error": {"code": "429", "message": "Requests to the Custom Form - Get Analyze Form Result Operation under Form Recognizer API (v2.0) have exceeded rate limit of your current FormRecognizer F0 pricing tier. Please retry after 4 seconds. To increase your rate limit switch to a paid tier."}}
# GET analyze results failed:
# 'status'
# GET analyze results failed:
# ...
